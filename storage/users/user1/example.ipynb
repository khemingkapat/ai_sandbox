# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
matrix = np.random.random((100,5))

# %%
df = pd.DataFrame(matrix)
df
# Out:
#            0         1         2         3         4
# 0   0.324033  0.725374  0.489187  0.088224  0.667012
# 1   0.498234  0.372948  0.188223  0.209454  0.925411
# 2   0.861453  0.800970  0.322450  0.589246  0.419940
# 3   0.573568  0.479671  0.840728  0.459555  0.822806
# 4   0.011691  0.400346  0.159256  0.640744  0.407989
# ..       ...       ...       ...       ...       ...
# 95  0.764789  0.969721  0.550582  0.976790  0.588781
# 96  0.540145  0.914051  0.352231  0.814231  0.313513
# 97  0.307490  0.634724  0.306623  0.302102  0.307394
# 98  0.193851  0.295369  0.713695  0.800414  0.769077
# 99  0.242209  0.001045  0.086004  0.473244  0.820222
#
# [100 rows x 5 columns]

# %%
df.columns = list("ABCDE")

# %%
df.plot.line(y="A")
plt.title("Randomized Value")
plt.show()
